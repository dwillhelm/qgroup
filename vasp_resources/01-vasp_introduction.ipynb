# %%
from vasp_python import VASPRelax

poscar_file_path = './example_calc/runid_112/POSCAR'
kpoints_file_path = './example_calc/runid_112/KPOINTS'
incar_file_path  = './example_calc/runid_112/INCAR'

vasp_relax = VASPRelax(
    poscar_file_path=poscar_file_path,
    kpoints_file_path=kpoints_file_path, 
    incar_file_path=incar_file_path)

vasp_relax.display_incar()
# Out:
# # VDW SCF for BANDDOS  INCAR Template
#
# # Startparams
#
# PREC = Accurate
#
# ISTART = 1          # 0: begin from scatch, 1:continue job from WAVECAR
#
# ISPIN  = 1          # spin polarization (i.e. magnetic moments) --> 1:OFF 0:ON
#
# ICHARG = 11 	    # read charge data from file
#
#
#
# # Write flags
#
# LWAVE  = .TRUE.        # write WAVECAR file
#
# LCHARG = .TRUE.        # write CHGCAR file
#
# LVTOT = .TRUE.
#
# LVHAR = .TRUE.
#
#
#
# # Parallelization
#
# NPAR = 2
#
#
#
# # Custom Tags
#
# M_FIXLATVEC = 0 0 1
#
#
#
# # Electronic Relaxation
#
# ALGO = Fast
#
# LREAL = .FALSE.         # real space projections T/F
#
# ENCUT  = 500            # cutoff energy for planewave basis set # Maybe change this for each HS
#
# EDIFF  = 1e-6           # stopping crit for elec relax loop (ELM)
#
#
#
# LMAXMIN = 4		# controls up to which l-quantum number passed/used written to the CHGCAR file
#
#
#
# # Ionic Relaxation
#
# EDIFFG = -0.02          # stopping crit for ionic relax loop (IOM)
# ...
